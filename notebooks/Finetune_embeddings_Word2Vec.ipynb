# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd '/content/drive/MyDrive/Github/Male_Gaze_NLP/src/'

from Finetune_embeddings_Word2Vec import train_embeddings
from tqdm.notebook import tqdm
import os
import re
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Github/Male_Gaze_NLP/src
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [==================================================] 100.0% 66.0/66.0MB downloaded

# %%
novels_dir = '/content/drive/MyDrive/NLU1012_Project/novels/'
model_dir = '/content/drive/MyDrive/NLU1012_Project/word_embeddings/'

for filename in tqdm(os.listdir(novels_dir)[10:]):
    doc_name = re.match("^[^.]+", filename).group()
    train_embeddings(doc_name, novels_dir,model_dir)
# Out:
#   0%|          | 0/45 [00:00<?, ?it/s]
